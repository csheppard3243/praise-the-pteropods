# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sc
import numpy as np
from scipy.stats import linregress
import cartopy.crs as ccrs
import seaborn as sns
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import xarray as xr
import matplotlib.colors as mcolors

# %%
#Map for Pteropod Datasets

#create figure
plt.figure(figsize=(10,6))

#plot projection
ax = plt.axes(projection=ccrs.PlateCarree())

#plot land, coastlines, and ocean features
ax.add_feature(cfeature.LAND, facecolor='lemonchiffon', zorder=2)
ax.add_feature(cfeature.COASTLINE, zorder=1, linewidth=0.5)
ax.add_feature(cfeature.OCEAN, color='lightblue')

#add stations and station ids
station_lons = [-74.7, -125, -36.02 ]  
station_lats = [26.14, 44.583, -31.65]
station_id = ['Sedimentary Pteropods','Sediment Trap Pterpods', 'Sergent Pteropods']

#scatter plot stations
ax.scatter(station_lons, station_lats, color='red', s=30, transform=ccrs.PlateCarree(), label='Pteropod ID', zorder=3)

#add legend
# ax.legend(loc='lower left')

#add station labels 
for lon, lat, name in zip(station_lons, station_lats, station_id):
    ax.text(lon - 12, lat + 1, name, color='black', fontsize=9,
            transform=ccrs.PlateCarree(), zorder=4, fontweight='bold')

#set title
ax.set_title('Map of Pteropod Sample Locations')

#show map
plt.show()

# %%
#coordinates
lat_pt = 26.14
lon_pt = -74.7

# to select nearest grid point from the dataset
depth = da.sel(lat=lat_pt, lon=lon_pt, method='nearest').values
print(f"Water column depth at ({lat_pt}, {lon_pt}) = {depth} meters")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 6
#       3 lon_pt = -74.7
#       5 # to select nearest grid point from the dataset
# ----> 6 depth = da.sel(lat=lat_pt, lon=lon_pt, method='nearest').values
#       7 print(f"Water column depth at ({lat_pt}, {lon_pt}) = {depth} meters")
#
# NameError: name 'da' is not defined

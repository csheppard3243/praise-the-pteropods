# %%
#import packages 

import pandas as pd
import matplotlib.pyplot as plt
import scipy as sc
import numpy as np
from scipy.stats import linregress

# %%
ds = pd.read_excel('columbiariveranalysis.xlsx', sheet_name= 'Sheet1') 
df = pd.read_excel('columbiariveranalysis.xlsx', sheet_name= 'Sheet2')
df.columns
# Out:
# Index(['Unnamed: 0', 'date', 'time', 'Unnamed: 3', 'flow', 'Unnamed: 5',
#        'date ', 'Label', 'slide', 'middle date', 'Sr/Ca [mmol/mol]',
#        'Ba/Ca [umol/mol]', 'U/Ca [nmol/mol]', 'Na_Ca [mmol/mol]',
#        'Mg_Ca [mmol/mol]', 'Mn_Ca [umol/mol]', 'Fe_Ca [umol/mol]',
#        'Al_Ca [umol/mol]', 'Unnamed: 18', 'sed trap', 'number on slide',
#        'start date', 'end date ', 'avg date'],
#       dtype='object')

# %%
datep = ds['date ']
datef = ds['date']
f = ds['flow']
ba = ds['Ba/Ca [umol/mol]']


datep2 = df['date ']
datef2 = df['date']
f2 = df['flow']
ba2 = df['Ba/Ca [umol/mol]']
fe2 = df['Fe_Ca [umol/mol]']
mn2 = df['Mn_Ca [umol/mol]']
u2 = df['U/Ca [nmol/mol]']
sr2 = df['Sr/Ca [mmol/mol]']
na2 = df['Na_Ca [mmol/mol]']
mg2 = df['Mg_Ca [mmol/mol]']
al2 = df['Al_Ca [umol/mol]']
middate = df['middle date']

# %%
#water column cup # analysis

# print(wpterodatanonan.columns)
fig, ax1= plt.subplots(figsize=(10,6))

ax2 = ax1.twinx()


# ax1.plot(datep, ba, color= 'orange')
ax1.scatter(datef, f, color='b', label = 'Flow')
ax1.plot(datef, f, color='b')
ax2.scatter(datep,  ba, color= 'orange', label= 'Ba/Ca')

label1= ('Ba/Ca') 
label2 = ('flow')
plt.xlabel('Time (Year-Month)')
ax2.tick_params(labelrotation=90)
ax2.set_ylabel('Ba/Ca (umol/mol)')
ax1.set_ylabel('Flow')
plt.title('Time Series of Ba/Ca vs U/Ca Ratio Variation in Water Column Pteropods')
ax1.set_xlabel('Time (Year-Month)')

#add legend
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper right')

# %%
fig, ax = plt.subplots(figsize = (10,6))


twin1 = ax.twinx()
twin2 = ax.twinx()
twin3 = ax.twinx()

# Offset the right spine of twin2.  The ticks and label have already been
# placed on the right by twinx above.
twin2.spines.right.set_position(("axes", 1.2))
twin3.spines.right.set_position(("axes", 1.4))

p2 = twin1.scatter(datep2, mn2, label="Mn/Ca", color='b')
p3 = twin2.scatter(datep2, fe2, label="Fe/Ca", color = 'r')
p4 = twin3.scatter(datep2, ba2, label="Ba/Ca", color ='g')
p1 = ax.scatter(datef2, f2, label="Flow", color ='orange')


ax.set_xlabel("Time (Year-Month)")
ax.set_ylabel("Mn/Ca")
twin1.set_ylabel("Fe/Ca")
twin2.set_ylabel("Ba/Ca")
twin3.set_ylabel("Flow Speed")



# ax.legend(handles=[p1, p2, p3,p4])



handles = [p1, p2, p3,p4]
labels = [h.get_label() for h in handles]
ax.legend(handles, labels, loc="upper left")

plt.show()

# %%
#water column cup # analysis

# print(wpterodatanonan.columns)
fig, ax1= plt.subplots(figsize=(10,6))

ax2 = ax1.twinx()


# ax1.plot(datep, ba, color= 'orange')
ax1.scatter(datef2, f2, color='b', label = 'Flow')
ax1.plot(datef2, f2, color='b')
ax2.scatter(datep2,  mn2, color= 'orange', label= 'Mn/Ca')

label1= ('Mn/Ca') 
label2 = ('flow')
plt.xlabel('Time (Year-Month)')
ax2.tick_params(labelrotation=90)
ax2.set_ylabel('Mn/Ca (umol/mol)')
ax1.set_ylabel('Flow')
plt.title('Time Series of Mn/Ca vs Columbia River Flow Rate in Water Column Pteropods')
ax2.set_xlabel('Time (Year-Month)')

#add legend
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper right')

# %%
#water column cup # analysis

# print(wpterodatanonan.columns)
fig, ax1= plt.subplots(figsize=(10,6))

ax2 = ax1.twinx()


# ax1.plot(datep, ba, color= 'orange')
ax1.scatter(datef2, f2, color='b', label = 'Flow')
ax1.plot(datef2, f2, color='b')
ax2.scatter(datep2,  fe2, color= 'orange', label= 'Fe/Ca')

label1= ('Fe/Ca') 
label2 = ('flow')
plt.xlabel('Time (Year-Month)')
ax2.tick_params(labelrotation=90)
ax2.set_ylabel('Fe/Ca (umol/mol)')
ax1.set_ylabel('Flow')
plt.title('Time Series of Fe/Ca vs Columbia River Flow Rate in Water Column Pteropods')
ax2.set_xlabel('Time (Year-Month)')

#add legend
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper right')

# %%
#getting 3 day flow averages
datef2 = pd.to_datetime(datef2)

f_3day = df['flow'].resample('3D').mean()

day3 = f_3day.index

f3 = f_3day.values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[325], line 4
#       1 #getting 3 day flow averages
#       2 datef2 = pd.to_datetime(datef2)
# ----> 4 f_3day = df['flow'].resample('3D').mean()
#       6 day3 = f_3day.index
#       8 f3 = f_3day.values
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:9834, in NDFrame.resample(self, rule, axis, closed, label, convention, kind, on, level, origin, offset, group_keys)
#    9831 else:
#    9832     kind = None
# -> 9834 return get_resampler(
#    9835     cast("Series | DataFrame", self),
#    9836     freq=rule,
#    9837     label=label,
#    9838     closed=closed,
#    9839     axis=axis,
#    9840     kind=kind,
#    9841     convention=convention,
#    9842     key=on,
#    9843     level=level,
#    9844     origin=origin,
#    9845     offset=offset,
#    9846     group_keys=group_keys,
# ...

# %%
#water column cup # analysis

# print(wpterodatanonan.columns)
fig, ax1= plt.subplots(figsize=(10,6))

ax2 = ax1.twinx()

# ax1.plot(datep, ba, color= 'orange')
ax1.scatter(day3,f3, color='b', label = 'Flow')
ax1.plot(day3, f3, color='b')
ax2.scatter(datep2,  fe2, color= 'orange', label= 'Fe/Ca')

label1= ('Fe/Ca') 
label2 = ('flow')
plt.xlabel('Time (Year-Month)')
ax2.tick_params(labelrotation=90)
ax2.set_ylabel('Fe/Ca (umol/mol)')
ax1.set_ylabel('Flow')
plt.title('Time Series of Fe/Ca vs Columbia River Flow Rate in Water Column Pteropods')
ax2.set_xlabel('Time (Year-Month)')

#add legend
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper right')

# %%
fig, ax = plt.subplots(figsize = (10,6))


twin1 = ax.twinx()
twin2 = ax.twinx()
twin3 = ax.twinx()

# Offset the right spine of twin2.  The ticks and label have already been
# placed on the right by twinx above.
twin2.spines.right.set_position(("axes", 1.2))
twin3.spines.right.set_position(("axes", 1.4))

p2 = twin1.scatter(datep2, mg2, label="Mg/Ca", color='b')
p3 = twin2.scatter(datep2, u2, label="U/Ca", color = 'r')
p4 = twin3.scatter(datep2, ba2, label="Ba/Ca", color ='g')
p1 = ax.scatter(day3, f3, label="Flow", color ='orange')
p1_ = ax.plot(day3, f3, label="Flow", color ='orange')

ax.set_xlabel("Time (Year-Month)")
ax.set_ylabel("Flow Speed")
twin1.set_ylabel("Mg/Ca (mmol/mol)")
twin2.set_ylabel("U/Ca (nmol/mol)")
twin3.set_ylabel("Ba/Ca (umol/mol)")



# ax.legend(handles=[p1_, p2, p3,p4])



handles = [p1, p2, p3,p4]
labels = [h.get_label() for h in handles]
ax.legend(handles, labels, loc="upper left")
plt.title('3-Day Average Flow of Columbia River vs U/Ca, Ba/Ca, and Mg/Ca')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (10,6))


twin1 = ax.twinx()
twin2 = ax.twinx()
twin3 = ax.twinx()

# Offset the right spine of twin2.  The ticks and label have already been
# placed on the right by twinx above.
twin2.spines.right.set_position(("axes", 1.2))
twin3.spines.right.set_position(("axes", 1.4))

p2 = twin1.scatter(datep2, mn2, label="Mn/Ca", color='b')
p3 = twin2.scatter(datep2, fe2, label="Fe/Ca", color = 'r')
p4 = twin3.scatter(datep2, ba2, label="Ba/Ca", color ='g')
p1 = ax.scatter(day3, f3, label="Flow", color ='orange')
p1_ = ax.plot(day3, f3, label="Flow", color ='orange')

ax.set_xlabel("Time (Year-Month)")
twin1.set_ylabel("Mn/Ca (umol/mol)")
twin2.set_ylabel("Fe/Ca (umol/mol)")
twin3.set_ylabel("Ba/Ca (umol/mol)")
ax.set_ylabel("Flow Speed")



# ax.legend(handles=[p1, p2, p3,p4])



handles = [p1, p2, p3,p4]
labels = [h.get_label() for h in handles]
ax.legend(handles, labels, loc="upper left")
plt.title('3-Day Average Flow of Columbia River vs Mn/Ca, Fe/Ca, and Ba/Ca')
plt.show()

# %%
#water column cup # analysis

# print(wpterodatanonan.columns)
fig, ax1= plt.subplots(figsize=(10,6))

ax2 = ax1.twinx()

# ax1.plot(datep, ba, color= 'orange')
ax1.scatter(day3,f3, color='b', label = 'Flow')
ax1.plot(day3, f3, color='b')
ax2.scatter(datep2,  u2, color= 'orange', label= 'U/Ca')

label1= ('U/Ca') 
label2 = ('flow')
plt.xlabel('Time (Year-Month)')
ax2.tick_params(labelrotation=90)
ax2.set_ylabel('U/Ca (nmol/mol)')
ax1.set_ylabel('Flow')
plt.title('3-Day Average Flow of Columbia River vs U/Ca')
ax1.set_xlabel('Time (Year-Month)')

#add legend
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper right')

# %%
#water column cup # analysis

# print(wpterodatanonan.columns)
fig, ax1= plt.subplots(figsize=(10,6))

ax2 = ax1.twinx()

# ax1.plot(datep, ba, color= 'orange')
ax1.scatter(day3,f3, color='b', label = 'Flow')
ax1.plot(day3, f3, color='b')
ax2.scatter(datep2,  mg2, color= 'orange', label= 'Mg/Ca')

label1= ('Mg/Ca (mmol/mol)') 
label2 = ('flow')
plt.xlabel('Time (Year-Month)')
ax2.tick_params(labelrotation=90)
ax2.set_ylabel('Mg/Ca (mmol/mol)')
ax1.set_ylabel('Flow')
plt.title('3-Day Average Flow of Columbia River vs Mg/Ca')
ax1.set_xlabel('Time (Year-Month)')

#add legend
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper right')

# %%
fig, ax = plt.subplots(figsize = (10,6))


twin1 = ax.twinx()
twin2 = ax.twinx()


# Offset the right spine of twin2.  The ticks and label have already been
# placed on the right by twinx above.
twin2.spines.right.set_position(("axes", 1.2))
twin3.spines.right.set_position(("axes", 1.4))

p2 = twin1.scatter(datep2, mg2, label="Mg/Ca", color='b')
p3 = twin2.scatter(datep2, u2, label="U/Ca", color = 'r')

p1 = ax.scatter(day3, f3, label="Average 3 Day Flow", color ='orange')
p1_ = ax.plot(day3, f3, label="Flow", color ='orange')

ax.set_xlabel("Time (Year-Month)")

twin1.set_ylabel("Mg/Ca (mmol/mol)")
twin2.set_ylabel("U/Ca (nmol/mol)")
ax.set_ylabel("Flow Speed")



# ax.legend(handles=[p1_, p2, p3,p4])



handles = [p1, p2, p3]
labels = [h.get_label() for h in handles]
ax.legend(handles, labels, loc="upper left")
plt.title('3-Day Average Flow of Columbia River vs Mg/Ca and U/Ca')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (10,6))


twin1 = ax.twinx()
twin2 = ax.twinx()


# Offset the right spine of twin2.  The ticks and label have already been
# placed on the right by twinx above.
twin2.spines.right.set_position(("axes", 1.2))
twin3.spines.right.set_position(("axes", 1.4))

p2 = twin1.scatter(middate, mg2, label="Mg/Ca", color='b')
p3 = twin2.scatter(middate, u2, label="U/Ca", color = 'r')

p1 = ax.scatter(day3, f3, label="Average 3 Day Flow", color ='orange')
p1_ = ax.plot(day3, f3, label="Flow", color ='orange')

ax.set_xlabel("Time (Year-Month)")

twin1.set_ylabel("Mg/Ca (mmol/mol)")
twin2.set_ylabel("U/Ca (nmol/mol)")
ax.set_ylabel("Flow Speed")



# ax.legend(handles=[p1_, p2, p3,p4])



handles = [p1, p2, p3]
labels = [h.get_label() for h in handles]
ax.legend(handles, labels, loc="upper left")
plt.title('3-Day Average Flow of Columbia River vs Mg/Ca and U/Ca Cup Number')
plt.show()

# %%
# Put data into a DataFrame
df_mg = pd.DataFrame({"middate": pd.to_datetime(middate),"MgCa": mg2})


# Group by date: one mean & std per middate
mg_stats = df_mg.groupby("middate")["MgCa"].agg(["mean", "std"]).reset_index()

x_mg    = mg_stats["middate"]       # same length
y_mg    = mg_stats["mean"]          # same length
yerr_mg = mg_stats["std"]           # same length

# Put data into a DataFrame
df_u = pd.DataFrame({"middate": pd.to_datetime(middate),"UCa": u2}).dropna(subset=["middate", "UCa"])

# Group by date: one mean & std per middate
u_stats = df_u.groupby("middate")["UCa"].agg(["mean", "std"]).reset_index()

x_u    = u_stats["middate"]
y_u    = u_stats["mean"]
yerr_u = u_stats["std"]


fig, ax = plt.subplots(figsize=(10,6))

twin1 = ax.twinx()
twin2 = ax.twinx()
twin2.spines.right.set_position(("axes", 1.2))

# Mg/Ca suite points with std
mg_err = twin1.errorbar(x_mg, y_mg, yerr=yerr_mg,fmt='o', capsize=4, label="Mg/Ca (±SD)", color = 'g')

# U/Ca suite points with std
u_err = twin2.errorbar(x_u, y_u, yerr=yerr_u,fmt='o', capsize=4, label="U/Ca (±SD)", color ='b')

# Flow (3-day avg)
flow_scatter = ax.scatter(day3, f3, label="3-Day Flow Avg", color = 'r')
flow_line, = ax.plot(day3, f3, label="3-Day Flow Avg", color = 'r')

# Labels
ax.set_xlabel("Time (Year-Month)")
ax.set_ylabel("Flow Speed")
twin1.set_ylabel("Mg/Ca (mmol/mol)")
twin2.set_ylabel("U/Ca (nmol/mol)")

# Legend
handles = [flow_scatter, mg_err, u_err]
labels = [h.get_label() for h in handles]
ax.legend(handles, labels, loc="upper left")

plt.title('3-Day Average Flow of Columbia River vs Mg/Ca and U/Ca Cup Averages')

plt.tight_layout()
plt.show()

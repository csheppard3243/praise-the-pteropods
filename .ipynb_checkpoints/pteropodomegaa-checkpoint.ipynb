# %%
#import packages 

import pandas as pd
import matplotlib.pyplot as plt
import scipy as sc
import numpy as np
from scipy.stats import linregress
import gsw

# %%
#load in datafiles 

dw = pd.read_excel('Pteropod_summary_MeCa.xlsx', sheet_name= 'ODV Water Column 1') 
ds = pd.read_excel('Pteropod_summary_MeCa.xlsx', sheet_name= 'ODV Sediments') 
df = pd.read_excel('Pteropod_summary_MeCa.xlsx', sheet_name= 'ODV Sergent')

data = pd.read_excel('Pteropod_summary_MeCa.xlsx', sheet_name= 'Sheet1', header = 1)
print(data.columns)
# Out:
# Index(['pteropod type', 'collection depth ', 'thermocline',
#        'aragonite saturation at collection depth',
#        'aragonite saturation at thermocline', 'temp at collection depth',
#        'temp at thermocline', 'salinity at collection depth',
#        'salinity at thermocline', 'Unnamed: 9', 'Sr/Ca [mmol/mol]',
#        'Ba/Ca [umol/mol]', 'U/Ca [nmol/mol]', 'Na_Ca [mmol/mol]',
#        'Mg_Ca [mmol/mol]', 'Mn_Ca [umol/mol]', 'Fe_Ca [umol/mol]',
#        'Al_Ca [umol/mol]'],
#       dtype='object')

# %%
zw = dw['depth (m)']
zs = ds['depth (m)']
zf = df['depth (m)']

wa = dw['OmegaA']
sa = ds['OmegaA']
fa = df['OmegaA']

ws = dw['sal']
ss = ds['sal']
fs = df['sal']

wt = dw['temp']
st =ds['temp']
ft = df['temp']

# %%
#graph 1: Omega A for all datasets

fig, axes = plt.subplots(1,3, figsize=(15,6))

axes[1].scatter(wa, zw)
axes[0].scatter(sa, zs)
axes[2].scatter(fa, zf)

axes[0].invert_yaxis()
axes[1].invert_yaxis()
axes[2].invert_yaxis()

axes[0].set_title("Sedimentary Pteropods (26.14°N, 74.7°W)", fontsize =12)

axes[1].set_title("Water Column Pteropods (44.58°N, 125°W)", fontsize =12)

axes[2].set_title("Sergent Pteropods (31.65°S, 36.02°W)", fontsize =12)

fig.supxlabel("Aragonite Saturation State", fontsize =15)
fig.supylabel("Depth (m)", fontsize =15)
fig.suptitle('Aragonite Saturatio State Profiles for Pteropod Types', fontsize = 20)
# Out:
# Text(0.5, 0.98, 'Aragonite Saturatio State Profiles for Pteropod Types')

# %%
#graph 1: Omega A for all datasets

plt.plot(figsize=(10,6))

plt.scatter(wa, zw, color = 'r', label= 'Water Column')
plt.scatter(sa, zs, color = 'b', label = 'Sedimentary')
plt.scatter(fa, zf, color = 'g', label = "Sergent")

plt.gca().invert_yaxis()


plt.title("Depth Profile of Aragonite Saturation for Pteropod Types", fontsize =15)
plt.legend()
plt.ylabel('Depth (m)')
# Out:
# Text(0, 0.5, 'Depth (m)')

# %%
#graph 1: Omega A for all datasets

plt.plot(figsize=(10,6))

plt.scatter(wa, zw, color = 'r', label= 'Water Column')
plt.scatter(sa, zs, color = 'b', label = 'Sedimentary')
plt.scatter(fa, zf, color = 'g', label = "Sergent")




plt.title("Depth Profile of Aragonite Saturation for Pteropod Types", fontsize =15)
plt.legend()
plt.ylabel('Depth (m)')
plt.xlabel('Aragonite Saturation State')

plt.arrow(0.7, 2880, 0.5, 2, width=0.05, ec ='r')
plt.text(1.3, 2880,'Sediment Trap Collection Depth', color='red', fontsize=10, ha='left')

plt.arrow(1.3, 1312, 0.5, 2, width=0.05, ec ='b')
plt.text(2.0, 1312,'Sediment Core Depth', color='b', fontsize=10, ha='left')

plt.arrow(1.2, 2158, 0.5, 2, width=0.05, ec ='g')
plt.text(2.0, 2158,'Sediment Core Depth', color='g', fontsize=10, ha='left')


plt.gca().invert_yaxis()

# %%
#graph 1: Omega A for all datasets

plt.plot(figsize=(10,6))

plt.scatter(wa, zw, color = 'r', label= 'Water Column')
plt.scatter(sa, zs, color = 'b', label = 'Sedimentary')
plt.scatter(fa, zf, color = 'g', label = "Sergent")




plt.title("Depth Profile of Aragonite Saturation for Pteropod Types for Upper ", fontsize =15)
plt.legend(loc = 'lower center')
plt.ylabel('Depth (m)')
plt.xlabel('Aragonite Saturation State')
plt.ylim(0,300)
plt.gca().invert_yaxis()

plt.arrow(0.7, 225, 0.5, 2, width=0.05, ec ='r')
plt.text(1.3, 225,'Thermocline', color='red', fontsize=10, ha='left')

plt.arrow(3, 80, 0.5, 2, width=0.05, ec ='b')
plt.text(2.3, 78,'Thermocline', color='b', fontsize=10, ha='left')

plt.arrow(3, 150, 0.5, 2, width=0.05, ec ='g')
plt.text(2.3, 145,'Thermocline', color='g', fontsize=10, ha='left')
# Out:
# Text(2.3, 145, 'Thermocline')

# %%
#graph 1: Omega A for all datasets

plt.plot(figsize=(10,6))

plt.scatter(wt,wa, color = 'r', label= 'Water Column')
plt.scatter(st,sa, color = 'b', label = 'Sedimentary')
plt.scatter(ft,fa, color = 'g', label = "Sergent")

plt.gca().invert_yaxis()


plt.title("Aragonite Saturation vs Temperature for Pteropod Types", fontsize =15)
plt.legend()
plt.xlabel('Temperature ')
plt.ylabel('Aragonite Saturation State')
plt.gca().invert_yaxis()

plt.arrow(7, 0.72, 0.5, 0.5, width=0.05, ec ='black')
plt.text(7, 0.5,'Sediment Trap Collection Depth', color='black', fontsize=10, ha='left')

plt.arrow(25.06, 3.53, 0.5, 0.5, width=0.05, ec ='b')
plt.text(25.06, 3.53,'Sediment Core Depth', color='b', fontsize=10, ha='left')

plt.arrow(18.79, 3.39, 0.5, 0.5, width=0.05, ec ='g')
plt.text(18.79, 3.39,'Sediment Core Depth', color='g', fontsize=10, ha='left')
# Out:
# Text(18.79, 3.39, 'Sediment Core Depth')

# %%
#graph 1: Omega A for all datasets

plt.plot(figsize=(10,6))

plt.scatter(ws,wa, color = 'r', label= 'Water Column')
plt.scatter(ss,sa, color = 'b', label = 'Sedimentary')
plt.scatter(fs,fa, color = 'g', label = "Sergent")

plt.gca().invert_yaxis()


plt.title("Aragonite Saturation vs Salinity for Pteropod Types", fontsize =15)
plt.legend()
plt.xlabel('Salinity')
plt.ylabel('Aragonite Saturation State')
plt.gca().invert_yaxis()

# %%
#density analysis

fig, ax1= plt.subplots(figsize=(10,6))

ax2 = ax1.twiny()

ax1.scatter(wt, zw, color= 'orange', label= 'Water Column Temperature')
ax1.scatter(st, zs, color= 'b', label = 'Sedimentary Temperature')
ax1.scatter(ft, zf, color = 'g', label = 'Sergent Temperature') 
ax2.scatter(ws, zw, color= 'orange', marker = 's', label = 'Water Column Salinity')
ax2.scatter(ss, zs, color='b', marker = 's', label = 'Sedimentary Salinity')
ax2.scatter(fs, zf, color='g', marker = 's', label = 'Sergent Salinity')


ax1.set_xlabel('Temperature °C')
ax2.set_xlabel('Salinity')
plt.title('Depth Profile of Temperature and Salinity for Pteropod Types')
plt.gca().invert_yaxis()

#add legend
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='lower center')

# %%
#density analysis

fig, ax1= plt.subplots(figsize=(10,6))

ax2 = ax1.twiny()

ax1.scatter(wt, zw, color= 'orange', label= 'Temperature')
ax2.scatter(ws, zw, color= 'b', marker = 's', label= 'Salinity')



ax1.set_xlabel('Temperature °C')
ax2.set_xlabel('Salinity')
plt.title('Depth Profile of Temperature and Salinity for Water Column Pteropods')
plt.gca().invert_yaxis()

#add legend
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='lower center')

# %%
# Figure out boudaries (mins and maxs)
smin = ws.min() - (0.01 * ws.min())
smax = ws.max() + (0.01 * ws.max())
tmin = wt.min() - (0.1 * wt.max())
tmax = wt.max() + (0.1 * wt.max())
 
# Calculate how many gridcells we need in the x and y dimensions
xdim = round((smax-smin)/0.1+1,0)
ydim = round((tmax-tmin)+1,0)
 
# Create empty grid of zeros
dens = np.zeros((int(ydim),int(xdim)))
 
# Create temp and salt vectors of appropiate dimensions
ti = np.linspace(1,int(ydim)-1,int(ydim))+tmin
si = np.linspace(1,int(xdim)-1,int(xdim))*0.1+smin
 
# Loop to fill in grid with densities
for j in range(0,int(ydim)):
    for i in range(0, int(xdim)):
        dens[j,i]=gsw.rho(si[i],ti[j],0)
 
# Substract 1000 to convert to sigma-t
dens = dens - 1000
 
# Plot data ***********************************************
fig1 = plt.figure()
ax1 = fig1.add_subplot(111)
CS = plt.contour(si,ti,dens, linestyles='dashed', colors='k')
plt.clabel(CS, fontsize=12, inline=1, fmt='%1.0f') # Label every second level
 
ax1.plot(ws,wt,'or',markersize=9)
 
ax1.set_xlabel('Salinity')
ax1.set_ylabel('Temperature (C)')
# Out:
# Text(0, 0.5, 'Temperature (C)')

# %%
datacsv = "Pteropod_summary_MeCa.csv"
data.to_csv(datacsv, index=False)
datacsv = pd.read_csv(datacsv)

w = datacsv[datacsv['pteropod type'].str.contains('water column')]
sed = datacsv[datacsv['pteropod type'].str.contains('sedimentary')]
ser = datacsv[datacsv['pteropod type'].str.contains('sergent', regex=False)]

wsatcd = w['aragonite saturation at collection depth']
ssatcd = sed['aragonite saturation at collection depth']
fsatcd = ser['aragonite saturation at collection depth']

wsatt = w['aragonite saturation at thermocline']
ssatt = sed['aragonite saturation at thermocline']
fsatt = ser['aragonite saturation at thermocline']

wtcd = w['temp at collection depth']
stcd = sed['temp at collection depth']
ftcd = ser['temp at collection depth']

wtt = w['temp at thermocline']
stt = sed['temp at thermocline']
ftt = ser['temp at thermocline']

wscd = w['salinity at collection depth']
sscd = sed['salinity at collection depth']
fscd = ser['salinity at collection depth']

wst = w['salinity at thermocline']
sst = sed['salinity at thermocline']
fst = ser['salinity at thermocline']

wna = w['Na_Ca [mmol/mol]']
sna = sed['Na_Ca [mmol/mol]']
fna = ser['Na_Ca [mmol/mol]']

wsr = w['Sr/Ca [mmol/mol]']
ssr = sed['Sr/Ca [mmol/mol]']
fsr = ser['Sr/Ca [mmol/mol]']

wba = w['Ba/Ca [umol/mol]']
sba = sed['Ba/Ca [umol/mol]']
fba = ser['Ba/Ca [umol/mol]']

wmg = w['Mg_Ca [mmol/mol]']
smg = sed['Mg_Ca [mmol/mol]']
fmg = ser['Mg_Ca [mmol/mol]']

wu = w['U/Ca [nmol/mol]']
su = sed['U/Ca [nmol/mol]']
fu = ser['U/Ca [nmol/mol]']

# %%
#graph 1: Omega A for all datasets

plt.plot(figsize=(10,6))

plt.scatter(wtcd, wna ,color = 'orange', label= 'Water Column')
plt.scatter(stcd, sna ,color = 'b', label = 'Sedimentary')

plt.title("Na/Ca (mmol/mol) vs Temperature for Pteropod Types at Collection Depth", fontsize =15)
plt.legend()
plt.xlabel('Temperature °C')
plt.ylabel('Na/Ca (mmol/mol)')
# Out:
# Text(0, 0.5, 'Na/Ca (mmol/mol)')

# %%
#graph 1: Omega A for all datasets

plt.plot(figsize=(10,6))

plt.scatter(wtt, wna ,color = 'orange', label= 'Water Column')
plt.scatter(stt, sna ,color = 'b', label = 'Sedimentary')

plt.title("Na/Ca (mmol/mol) vs Temperature for Pteropod Types at Thermocline", fontsize =15)
plt.legend()
plt.xlabel('Temperature °C')
plt.ylabel('Na/Ca (mmol/mol)')
# Out:
# Text(0, 0.5, 'Na/Ca (mmol/mol)')

# %%
#graph 1: Omega A for all datasets

plt.plot(figsize=(10,6))

plt.scatter(wscd, wna ,color = 'orange', label= 'Water Column')
plt.scatter(sscd, sna ,color = 'b', label = 'Sedimentary')

plt.title("Na/Ca (mmol/mol) vs Salinity for Pteropod Types at Collection Depth", fontsize =15)
plt.legend()
plt.xlabel('Salinity')
plt.ylabel('Na/Ca (mmol/mol)')
# Out:
# Text(0, 0.5, 'Na/Ca (mmol/mol)')

# %%
#graph 1: Omega A for all datasets

plt.plot(figsize=(10,6))

plt.scatter(wst, wna ,color = 'orange', label= 'Water Column')
plt.scatter(sst, sna ,color = 'b', label = 'Sedimentary')

plt.title("Na/Ca (mmol/mol) vs Salinity for Pteropod Types at Thermocline", fontsize =15)
plt.legend()
plt.xlabel('Salinity')
plt.ylabel('Na/Ca (mmol/mol)')
# Out:
# Text(0, 0.5, 'Na/Ca (mmol/mol)')

# %%
#graph 1: Omega A for all datasets

fig, axes = plt.subplots(3,2, figsize=(10,8))

axes[0,0].scatter(wtcd, wna ,color = 'orange', label= 'Water Column')
axes[0,0].scatter(stcd, sna ,color = 'b', label = 'Sedimentary')

axes[0,1].scatter(wtt, wna ,color = 'orange', label= 'Water Column')
axes[0,1].scatter(stt, sna ,color = 'b', label = 'Sedimentary')

axes[1,0].scatter(wscd, wna ,color = 'orange', label= 'Water Column')
axes[1,0].scatter(sscd, sna ,color = 'b', label = 'Sedimentary')

axes[1,1].scatter(wst, wna ,color = 'orange', label= 'Water Column')
axes[1,1].scatter(sst, sna ,color = 'b', label = 'Sedimentary')

axes[2,0].scatter(wsatcd, wna ,color = 'orange', label= 'Water Column')
axes[2,0].scatter(ssatcd, sna ,color = 'b', label = 'Sedimentary')

axes[2,1].scatter(wsatt, wna ,color = 'orange', label= 'Water Column')
axes[2,1].scatter(ssatt, sna ,color = 'b', label = 'Sedimentary')


axes[0,0].set_title("Na/Ca (mmol/mol) at Collection Depth")
axes[0,1].set_title('Na/Ca (mmol/mol) at Thermocline')

axes[0,0].set_xlabel('Temperature °C')
axes[0,1].set_xlabel('Temperature °C')

axes[1,0].set_xlabel('Salinity')
axes[1,1].set_xlabel('Salinity')

axes[2,0].set_xlabel('Aragonite Saturation State')
axes[2,1].set_xlabel('Aragonite Saturation State')

plt.legend()
fig.supylabel('Na/Ca (mmol/mol)')

fig.tight_layout()

# %%
fig, axes = plt.subplots(3,2, figsize=(10,8))

axes[0,0].scatter(wtcd, wsr ,color = 'orange', label= 'Water Column')
axes[0,0].scatter(stcd, ssr ,color = 'b', label = 'Sedimentary')
axes[0,0].scatter(ftcd, fsr ,color = 'g', label = 'Sergent')

axes[0,1].scatter(wtt, wsr ,color = 'orange', label= 'Water Column')
axes[0,1].scatter(stt, ssr ,color = 'b', label = 'Sedimentary')
axes[0,1].scatter(ftt, fsr ,color = 'g', label = 'Sergent')

axes[1,0].scatter(wscd, wsr ,color = 'orange', label= 'Water Column')
axes[1,0].scatter(sscd, ssr ,color = 'b', label = 'Sedimentary')
axes[1,0].scatter(fscd, fsr ,color = 'g', label = 'Sergent')

axes[1,1].scatter(wst, wsr ,color = 'orange', label= 'Water Column')
axes[1,1].scatter(sst, ssr ,color = 'b', label = 'Sedimentary')
axes[1,1].scatter(fst, fsr ,color = 'g', label = 'Sergent')

axes[2,0].scatter(wsatcd, wsr ,color = 'orange', label= 'Water Column')
axes[2,0].scatter(ssatcd, ssr ,color = 'b', label = 'Sedimentary')
axes[2,0].scatter(fsatcd, fsr ,color = 'g', label = 'Sergent')

axes[2,1].scatter(wsatt, wsr ,color = 'orange', label= 'Water Column')
axes[2,1].scatter(ssatt, ssr ,color = 'b', label = 'Sedimentary')
axes[2,1].scatter(fsatt, fsr ,color = 'g', label = 'Sergent')

axes[0,0].set_title("Sr/Ca (mmol/mol) at Collection Depth")
axes[0,1].set_title('Sr/Ca (mmol/mol) at Thermocline')

axes[0,0].set_xlabel('Temperature °C')
axes[0,1].set_xlabel('Temperature °C')

axes[1,0].set_xlabel('Salinity')
axes[1,1].set_xlabel('Salinity')

axes[2,0].set_xlabel('Aragonite Saturation State')
axes[2,1].set_xlabel('Aragonite Saturation State')

plt.legend()
fig.supylabel('Sr/Ca (mmol/mol)')

fig.tight_layout()

# %%
fig, axes = plt.subplots(3,2, figsize=(10,8))

axes[0,0].scatter(wtcd, wba ,color = 'orange', label= 'Water Column')
axes[0,0].scatter(stcd, sba ,color = 'b', label = 'Sedimentary')
axes[0,0].scatter(ftcd, fba ,color = 'g', label = 'Sergent')

axes[0,1].scatter(wtt, wba ,color = 'orange', label= 'Water Column')
axes[0,1].scatter(stt, sba ,color = 'b', label = 'Sedimentary')
axes[0,1].scatter(ftt, fba ,color = 'g', label = 'Sergent')

axes[1,0].scatter(wscd, wba ,color = 'orange', label= 'Water Column')
axes[1,0].scatter(sscd, sba ,color = 'b', label = 'Sedimentary')
axes[1,0].scatter(fscd, fba ,color = 'g', label = 'Sergent')

axes[1,1].scatter(wst, wba ,color = 'orange', label= 'Water Column')
axes[1,1].scatter(sst, sba ,color = 'b', label = 'Sedimentary')
axes[1,1].scatter(fst, fba ,color = 'g', label = 'Sergent')

axes[2,0].scatter(wsatcd, wba ,color = 'orange', label= 'Water Column')
axes[2,0].scatter(ssatcd, sba ,color = 'b', label = 'Sedimentary')
axes[2,0].scatter(fsatcd, fba ,color = 'g', label = 'Sergent')

axes[2,1].scatter(wsatt, wba ,color = 'orange', label= 'Water Column')
axes[2,1].scatter(ssatt, sba ,color = 'b', label = 'Sedimentary')
axes[2,1].scatter(fsatt, fba ,color = 'g', label = 'Sergent')

axes[0,0].set_title("Ba/Ca (umol/mol) at Collection Depth")
axes[0,1].set_title('Ba/Ca (umol/mol) at Thermocline')

axes[0,0].set_xlabel('Temperature °C')
axes[0,1].set_xlabel('Temperature °C')

axes[1,0].set_xlabel('Salinity')
axes[1,1].set_xlabel('Salinity')

axes[2,0].set_xlabel('Aragonite Saturation State')
axes[2,1].set_xlabel('Aragonite Saturation State')

plt.legend()
fig.supylabel('Ba/Ca (umol/mol)')

fig.tight_layout()

# %%
fig, axes = plt.subplots(3,2, figsize=(10,8))

axes[0,0].scatter(wtcd, wmg ,color = 'orange', label= 'Water Column')
axes[0,0].scatter(stcd, smg ,color = 'b', label = 'Sedimentary')
axes[0,0].scatter(ftcd, fmg ,color = 'g', label = 'Sergent')

axes[0,1].scatter(wtt, wmg ,color = 'orange', label= 'Water Column')
axes[0,1].scatter(stt, smg ,color = 'b', label = 'Sedimentary')
axes[0,1].scatter(ftt, fmg ,color = 'g', label = 'Sergent')

axes[1,0].scatter(wscd, wmg ,color = 'orange', label= 'Water Column')
axes[1,0].scatter(sscd, smg ,color = 'b', label = 'Sedimentary')
axes[1,0].scatter(fscd, fmg ,color = 'g', label = 'Sergent')

axes[1,1].scatter(wst, wmg ,color = 'orange', label= 'Water Column')
axes[1,1].scatter(sst, smg ,color = 'b', label = 'Sedimentary')
axes[1,1].scatter(fst, fmg ,color = 'g', label = 'Sergent')

axes[2,0].scatter(wsatcd, wmg ,color = 'orange', label= 'Water Column')
axes[2,0].scatter(ssatcd, smg ,color = 'b', label = 'Sedimentary')
axes[2,0].scatter(fsatcd, fmg ,color = 'g', label = 'Sergent')

axes[2,1].scatter(wsatt, wmg,color = 'orange', label= 'Water Column')
axes[2,1].scatter(ssatt, smg ,color = 'b', label = 'Sedimentary')
axes[2,1].scatter(fsatt, fmg ,color = 'g', label = 'Sergent')

axes[0,0].set_title("Mg/Ca (mmol/mol) at Collection Depth")
axes[0,1].set_title('Mg/Ca (mmol/mol) at Thermocline')

axes[0,0].set_xlabel('Temperature °C')
axes[0,1].set_xlabel('Temperature °C')

axes[1,0].set_xlabel('Salinity')
axes[1,1].set_xlabel('Salinity')

axes[2,0].set_xlabel('Aragonite Saturation State')
axes[2,1].set_xlabel('Aragonite Saturation State')

plt.legend()
fig.supylabel('Mg/Ca (mmol/mol)')

fig.tight_layout()

# %%
fig, axes = plt.subplots(3,2, figsize=(10,8))

axes[0,0].scatter(wtcd, wu ,color = 'orange', label= 'Water Column')
axes[0,0].scatter(stcd, su ,color = 'b', label = 'Sedimentary')
axes[0,0].scatter(ftcd, fu ,color = 'g', label = 'Sergent')

axes[0,1].scatter(wtt, wu ,color = 'orange', label= 'Water Column')
axes[0,1].scatter(stt, su ,color = 'b', label = 'Sedimentary')
axes[0,1].scatter(ftt, fu ,color = 'g', label = 'Sergent')

axes[1,0].scatter(wscd, wu ,color = 'orange', label= 'Water Column')
axes[1,0].scatter(sscd, su ,color = 'b', label = 'Sedimentary')
axes[1,0].scatter(fscd, fu ,color = 'g', label = 'Sergent')

axes[1,1].scatter(wst, wu ,color = 'orange', label= 'Water Column')
axes[1,1].scatter(sst, su ,color = 'b', label = 'Sedimentary')
axes[1,1].scatter(fst, fu ,color = 'g', label = 'Sergent')

axes[2,0].scatter(wsatcd, wu ,color = 'orange', label= 'Water Column')
axes[2,0].scatter(ssatcd, su ,color = 'b', label = 'Sedimentary')
axes[2,0].scatter(fsatcd, fu ,color = 'g', label = 'Sergent')

axes[2,1].scatter(wsatt, wu ,color = 'orange', label= 'Water Column')
axes[2,1].scatter(ssatt, su ,color = 'b', label = 'Sedimentary')
axes[2,1].scatter(fsatt, fu ,color = 'g', label = 'Sergent')

axes[0,0].set_title("U/Ca (nmol/mol) at Collection Depth")
axes[0,1].set_title('U/Ca (nmol/mol) at Thermocline')

axes[0,0].set_xlabel('Temperature °C')
axes[0,1].set_xlabel('Temperature °C')

axes[1,0].set_xlabel('Salinity')
axes[1,1].set_xlabel('Salinity')

axes[2,0].set_xlabel('Aragonite Saturation State')
axes[2,1].set_xlabel('Aragonite Saturation State')

plt.legend()
fig.supylabel('U/Ca (nmol/mol)')

fig.tight_layout()

# %%
fig, axes = plt.subplots(3,2, figsize=(10,8))

axes[0,0].scatter(wtcd, wu ,color = 'orange', label= 'Water Column')
axes[0,0].scatter(stcd, su ,color = 'b', label = 'Sedimentary')
# axes[0,0].scatter(ftcd, fu ,color = 'g', label = 'Sergent')

axes[0,1].scatter(wtt, wu ,color = 'orange', label= 'Water Column')
axes[0,1].scatter(stt, su ,color = 'b', label = 'Sedimentary')
# axes[0,1].scatter(ftt, fu ,color = 'g', label = 'Sergent')

axes[1,0].scatter(wscd, wu ,color = 'orange', label= 'Water Column')
axes[1,0].scatter(sscd, su ,color = 'b', label = 'Sedimentary')
# axes[1,0].scatter(fscd, fu ,color = 'g', label = 'Sergent')

axes[1,1].scatter(wst, wu ,color = 'orange', label= 'Water Column')
axes[1,1].scatter(sst, su ,color = 'b', label = 'Sedimentary')
# axes[1,1].scatter(fst, fu ,color = 'g', label = 'Sergent')

axes[2,0].scatter(wsatcd, wu ,color = 'orange', label= 'Water Column')
axes[2,0].scatter(ssatcd, su ,color = 'b', label = 'Sedimentary')
# axes[2,0].scatter(fsatcd, fu ,color = 'g', label = 'Sergent')

axes[2,1].scatter(wsatt, wu ,color = 'orange', label= 'Water Column')
axes[2,1].scatter(ssatt, su ,color = 'b', label = 'Sedimentary')
# axes[2,1].scatter(fsatt, fu ,color = 'g', label = 'Sergent')


axes[0,0].set_title("U/Ca (nmol/mol) at Collection Depth")
axes[0,1].set_title('U/Ca (nmol/mol) at Thermocline')

axes[0,0].set_xlabel('Temperature °C')
axes[0,1].set_xlabel('Temperature °C')

axes[1,0].set_xlabel('Salinity')
axes[1,1].set_xlabel('Salinity')

axes[2,0].set_xlabel('Aragonite Saturation State')
axes[2,1].set_xlabel('Aragonite Saturation State')

plt.legend()
fig.supylabel('U/Ca (nmol/mol)')

fig.tight_layout()
